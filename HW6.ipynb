# %% [markdown]
# ### 1. Сборка длинных ридов

# %% [markdown]
# Для запуска Canu посмотрим на размер генома:

# %%
ref_len = 0
f = open('./homework6/reference.fasta', 'r')
for line in f:
    if line.startswith('>'):
        pass
    else:
        line = line.strip()
        ref_len += len(line)
print(f'Genome size: {ref_len}')
# Out:
# Genome size: 4639675

# %%
! /Users/olga/miniconda3/pkgs/canu-1.5-pl5.22.0_1/bin/canu -p pacbio10 -d pacbio10 genomesize=4.7m -pacbio-raw ./homework6/pacbio_10x.fq
# Out:
# -- Canu release v1.5
# -- Detected Java(TM) Runtime Environment '1.8.0_152-release' (from '/Users/olga/miniconda3/bin/java').
# -- Detected gnuplot version '5.4 patchlevel 1' (from 'gnuplot') and image format 'png'.
# -- Detected 8 CPUs and 16 gigabytes of memory.
# -- No grid engine detected, grid disabled.
# --
# -- Run   2 jobs concurrently using    8 GB and   4 CPUs for stage 'meryl'.
# -- Run   1 job  concurrently using    6 GB and   8 CPUs for stage 'mhap (cor)'.
# -- Run   1 job  concurrently using    8 GB and   8 CPUs for stage 'overlapper (obt)'.
# -- Run   1 job  concurrently using    8 GB and   8 CPUs for stage 'overlapper (utg)'.
# -- Run   4 jobs concurrently using    8 GB and   2 CPUs for stage 'falcon_sense'.
# -- Run   8 jobs concurrently using    2 GB and   1 CPU  for stage 'ovStore bucketizer'.
# -- Run   8 jobs concurrently using    8 GB and   1 CPU  for stage 'ovStore sorting'.
# ...

# %%
! /Users/olga/miniconda3/pkgs/canu-1.5-pl5.22.0_1/bin/canu -p pacbio20 -d pacbio20 genomesize=4.7m -pacbio-raw ./homework6/pacbio_20x.fq
# Out:
# -- Canu release v1.5
# -- Detected Java(TM) Runtime Environment '1.8.0_152-release' (from '/Users/olga/miniconda3/bin/java').
# -- Detected gnuplot version '5.4 patchlevel 1' (from 'gnuplot') and image format 'png'.
# -- Detected 8 CPUs and 16 gigabytes of memory.
# -- No grid engine detected, grid disabled.
# --
# -- Run   2 jobs concurrently using    8 GB and   4 CPUs for stage 'meryl'.
# -- Run   1 job  concurrently using    6 GB and   8 CPUs for stage 'mhap (cor)'.
# -- Run   1 job  concurrently using    8 GB and   8 CPUs for stage 'overlapper (obt)'.
# -- Run   1 job  concurrently using    8 GB and   8 CPUs for stage 'overlapper (utg)'.
# -- Run   4 jobs concurrently using    8 GB and   2 CPUs for stage 'falcon_sense'.
# -- Run   8 jobs concurrently using    2 GB and   1 CPU  for stage 'ovStore bucketizer'.
# -- Run   8 jobs concurrently using    8 GB and   1 CPU  for stage 'ovStore sorting'.
# ...

# %%
! /Users/olga/miniconda3/pkgs/canu-1.5-pl5.22.0_1/bin/canu -p pacbio40 -d pacbio40 genomesize=4.7m -pacbio-raw ./homework6/pacbio_40x.fq
# Out:
# -- Canu release v1.5
# -- Detected Java(TM) Runtime Environment '1.8.0_152-release' (from '/Users/olga/miniconda3/bin/java').
# -- Detected gnuplot version '5.4 patchlevel 1' (from 'gnuplot') and image format 'png'.
# -- Detected 8 CPUs and 16 gigabytes of memory.
# -- No grid engine detected, grid disabled.
# --
# -- Run   2 jobs concurrently using    8 GB and   4 CPUs for stage 'meryl'.
# -- Run   1 job  concurrently using    6 GB and   8 CPUs for stage 'mhap (cor)'.
# -- Run   1 job  concurrently using    8 GB and   8 CPUs for stage 'overlapper (obt)'.
# -- Run   1 job  concurrently using    8 GB and   8 CPUs for stage 'overlapper (utg)'.
# -- Run   4 jobs concurrently using    8 GB and   2 CPUs for stage 'falcon_sense'.
# -- Run   8 jobs concurrently using    2 GB and   1 CPU  for stage 'ovStore bucketizer'.
# -- Run   8 jobs concurrently using    8 GB and   1 CPU  for stage 'ovStore sorting'.
# ...

# %%
! /Users/olga/miniconda3/pkgs/canu-1.5-pl5.22.0_1/bin/canu -p pacbio80 -d pacbio80 genomesize=4.7m -pacbio-raw ./homework6/pacbio_80x.fq
# Out:
# -- Canu release v1.5
# -- Detected Java(TM) Runtime Environment '1.8.0_152-release' (from '/Users/olga/miniconda3/bin/java').
# -- Detected gnuplot version '5.4 patchlevel 1' (from 'gnuplot') and image format 'png'.
# -- Detected 8 CPUs and 16 gigabytes of memory.
# -- No grid engine detected, grid disabled.
# --
# -- Run   2 jobs concurrently using    8 GB and   4 CPUs for stage 'meryl'.
# -- Run   1 job  concurrently using    6 GB and   8 CPUs for stage 'mhap (cor)'.
# -- Run   1 job  concurrently using    8 GB and   8 CPUs for stage 'overlapper (obt)'.
# -- Run   1 job  concurrently using    8 GB and   8 CPUs for stage 'overlapper (utg)'.
# -- Run   4 jobs concurrently using    8 GB and   2 CPUs for stage 'falcon_sense'.
# -- Run   8 jobs concurrently using    2 GB and   1 CPU  for stage 'ovStore bucketizer'.
# -- Run   8 jobs concurrently using    8 GB and   1 CPU  for stage 'ovStore sorting'.
# ...

# %% [markdown]
# ### 2. Сборка коротких ридов

# %% [markdown]
# Собираем с помощью Spades

# %%
! /Users/olga/Downloads/SPAdes-3.15.2/bin/spades.py -1 ./homework6/illumina.100x.1.fq -2 ./homework6/illumina.100x.2.fq -o illumina
# Out:
# == Warning ==  output dir is not empty! Please, clean output directory before run.
#
#
#
#
# == Warning ==  No assembly mode was specified! If you intend to assemble high-coverage multi-cell/isolate data, use '--isolate' option.
#
#
# Command line: /Users/olga/Downloads/SPAdes-3.15.2/bin/spades.py	-1	/Users/olga/Documents/BioinformaticsInstitute/NGS/homework6/illumina.100x.1.fq	-2	/Users/olga/Documents/BioinformaticsInstitute/NGS/homework6/illumina.100x.2.fq	-o	/Users/olga/Documents/BioinformaticsInstitute/NGS/illumina
#
# System information:
#   SPAdes version: 3.15.2
#   Python version: 3.7.7
#   OS: Darwin-20.3.0-x86_64-i386-64bit
#
# Output dir: /Users/olga/Documents/BioinformaticsInstitute/NGS/illumina
# Mode: read error correction and assembling
# Debug mode is turned OFF
#
# Dataset parameters:
#   Standard mode
# ...

# %% [markdown]
# ### 3. Гибридная сборка

# %% [markdown]
# Собираем с помощью Spades

# %%
! /Users/olga/Downloads/SPAdes-3.15.2/bin/spades.py -1 ./homework6/illumina.100x.1.fq -2 ./homework6/illumina.100x.2.fq --pacbio ./homework6/pacbio_10x.fq -o illumina_pacbio10
# Out:
# == Warning ==  output dir is not empty! Please, clean output directory before run.
#
#
#
#
# == Warning ==  No assembly mode was specified! If you intend to assemble high-coverage multi-cell/isolate data, use '--isolate' option.
#
#
# Command line: /Users/olga/Downloads/SPAdes-3.15.2/bin/spades.py	-1	/Users/olga/Documents/BioinformaticsInstitute/NGS/homework6/illumina.100x.1.fq	-2	/Users/olga/Documents/BioinformaticsInstitute/NGS/homework6/illumina.100x.2.fq	--pacbio	/Users/olga/Documents/BioinformaticsInstitute/NGS/homework6/pacbio_10x.fq	-o	/Users/olga/Documents/BioinformaticsInstitute/NGS/illumina_pacbio10
#
# System information:
#   SPAdes version: 3.15.2
#   Python version: 3.7.7
#   OS: Darwin-20.3.0-x86_64-i386-64bit
#
# Output dir: /Users/olga/Documents/BioinformaticsInstitute/NGS/illumina_pacbio10
# Mode: read error correction and assembling
# Debug mode is turned OFF
#
# Dataset parameters:
#   Standard mode
# ...

# %%
! /Users/olga/Downloads/SPAdes-3.15.2/bin/spades.py -1 ./homework6/illumina.100x.1.fq -2 ./homework6/illumina.100x.2.fq --pacbio ./homework6/pacbio_20x.fq -o illumina_pacbio20
# Out:
# == Warning ==  No assembly mode was specified! If you intend to assemble high-coverage multi-cell/isolate data, use '--isolate' option.
#
#
# Command line: /Users/olga/Downloads/SPAdes-3.15.2/bin/spades.py	-1	/Users/olga/Documents/BioinformaticsInstitute/NGS/homework6/illumina.100x.1.fq	-2	/Users/olga/Documents/BioinformaticsInstitute/NGS/homework6/illumina.100x.2.fq	--pacbio	/Users/olga/Documents/BioinformaticsInstitute/NGS/homework6/pacbio_20x.fq	-o	/Users/olga/Documents/BioinformaticsInstitute/NGS/illumina_pacbio20
#
# System information:
#   SPAdes version: 3.15.2
#   Python version: 3.7.7
#   OS: Darwin-20.3.0-x86_64-i386-64bit
#
# Output dir: /Users/olga/Documents/BioinformaticsInstitute/NGS/illumina_pacbio20
# Mode: read error correction and assembling
# Debug mode is turned OFF
#
# Dataset parameters:
#   Standard mode
# ...

# %%
! /Users/olga/Downloads/SPAdes-3.15.2/bin/spades.py -1 ./homework6/illumina.100x.1.fq -2 ./homework6/illumina.100x.2.fq --pacbio ./homework6/pacbio_40x.fq -o illumina_pacbio40
# Out:
# == Warning ==  No assembly mode was specified! If you intend to assemble high-coverage multi-cell/isolate data, use '--isolate' option.
#
#
# Command line: /Users/olga/Downloads/SPAdes-3.15.2/bin/spades.py	-1	/Users/olga/Documents/BioinformaticsInstitute/NGS/homework6/illumina.100x.1.fq	-2	/Users/olga/Documents/BioinformaticsInstitute/NGS/homework6/illumina.100x.2.fq	--pacbio	/Users/olga/Documents/BioinformaticsInstitute/NGS/homework6/pacbio_40x.fq	-o	/Users/olga/Documents/BioinformaticsInstitute/NGS/illumina_pacbio40
#
# System information:
#   SPAdes version: 3.15.2
#   Python version: 3.7.7
#   OS: Darwin-20.3.0-x86_64-i386-64bit
#
# Output dir: /Users/olga/Documents/BioinformaticsInstitute/NGS/illumina_pacbio40
# Mode: read error correction and assembling
# Debug mode is turned OFF
#
# Dataset parameters:
#   Standard mode
# ...

# %%
! /Users/olga/Downloads/SPAdes-3.15.2/bin/spades.py -1 ./homework6/illumina.100x.1.fq -2 ./homework6/illumina.100x.2.fq --pacbio ./homework6/pacbio_80x.fq -o illumina_pacbio80
# Out:
# == Warning ==  No assembly mode was specified! If you intend to assemble high-coverage multi-cell/isolate data, use '--isolate' option.
#
#
# Command line: /Users/olga/Downloads/SPAdes-3.15.2/bin/spades.py	-1	/Users/olga/Documents/BioinformaticsInstitute/NGS/homework6/illumina.100x.1.fq	-2	/Users/olga/Documents/BioinformaticsInstitute/NGS/homework6/illumina.100x.2.fq	--pacbio	/Users/olga/Documents/BioinformaticsInstitute/NGS/homework6/pacbio_80x.fq	-o	/Users/olga/Documents/BioinformaticsInstitute/NGS/illumina_pacbio80
#
# System information:
#   SPAdes version: 3.15.2
#   Python version: 3.7.7
#   OS: Darwin-20.3.0-x86_64-i386-64bit
#
# Output dir: /Users/olga/Documents/BioinformaticsInstitute/NGS/illumina_pacbio80
# Mode: read error correction and assembling
# Debug mode is turned OFF
#
# Dataset parameters:
#   Standard mode
# ...

# %% [markdown]
# ### 4. Сравним сборки с помощью quast

# %%
! /Users/olga/Downloads/quast-5.0.2/quast.py \
pacbio10/pacbio10.contigs.fasta \
pacbio20/pacbio20.contigs.fasta \
pacbio40/pacbio40.contigs.fasta \
pacbio80/pacbio80.contigs.fasta \
illumina/contigs.fasta \
illumina_pacbio10/contigs.fasta \
illumina_pacbio20/contigs.fasta \
illumina_pacbio40/contigs.fasta \
illumina_pacbio80/contigs.fasta \
-R homework6/reference.fasta \
-o quast_result
# Out:
# /Users/olga/Downloads/quast-5.0.2/quast.py pacbio10/pacbio10.contigs.fasta pacbio20/pacbio20.contigs.fasta pacbio40/pacbio40.contigs.fasta pacbio80/pacbio80.contigs.fasta illumina/contigs.fasta illumina_pacbio10/contigs.fasta illumina_pacbio20/contigs.fasta illumina_pacbio40/contigs.fasta illumina_pacbio80/contigs.fasta -R homework6/reference.fasta -o quast_result
#
# Version: 5.0.2, 0bb1dd1b
#
# System information:
#   OS: Darwin-20.3.0-x86_64-i386-64bit (macosx)
#   Python version: 3.7.7
#   CPUs number: 8
#
# Started: 2021-04-23 18:28:40
#
# Logging to /Users/olga/Documents/BioinformaticsInstitute/NGS/quast_result/quast.log
# NOTICE: Maximum number of threads is set to 2 (use --threads option to set it manually)
#
# CWD: /Users/olga/Documents/BioinformaticsInstitute/NGS
# Main parameters:
#   MODE: default, threads: 2, minimum contig length: 500, minimum alignment length: 65, \
#   ambiguity: one, threshold for extensive misassembly size: 1000
#
# Reference:
# ...

# %% [markdown]
# ### 5. Проанализируем результаты (на основе отчёта, сгенерированного quast)

# %%
import pandas as pd

# %%
quast_data = pd.read_csv('quast_result/report.tsv', sep='\t')
quast_data
# Out:
#                        Assembly pacbio10.contigs pacbio20.contigs  \
# 0           # contigs (>= 0 bp)               94               22
# 1        # contigs (>= 1000 bp)               94               22
# 2        # contigs (>= 5000 bp)               92               22
# 3       # contigs (>= 10000 bp)               89               21
# 4       # contigs (>= 25000 bp)               55               20
# 5       # contigs (>= 50000 bp)               24               18
# 6        Total length (>= 0 bp)          3540004          4598820
# 7     Total length (>= 1000 bp)          3540004          4598820
# 8     Total length (>= 5000 bp)          3530802          4598820
# 9    Total length (>= 10000 bp)          3506582          4591727
# 10   Total length (>= 25000 bp)          2917321          4575443
# 11   Total length (>= 50000 bp)          1757051          4506249
# 12                    # contigs               94               22
# ...

# %% [markdown]
# 1) **# contigs:** лучшее - pacbio40, pacbio80, худшие значения - pacbio10, illumina <br>
# 2) **Largest contig:** лучшее - pacbio40, pacbio80, худшие значения - pacbio10, illumina <br>
# 3) **Total length:** лучшее - pacbio40, pacbio80, но остальные значения, кроме pacbio10, также хорошие <br>
# 4) **N50:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10, неплохое значение по сравнению с другими показывает pacbio20 <br>
# 5) **NG50:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10, неплохое значение по сравнению с другими показывает pacbio20 <br>
# 6) **N75:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10, неплохое значение по сравнению с другими показывает pacbio20 <br>
# 7) **NG75:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10, неплохое значение по сравнению с другими показывает pacbio20 <br>
# 8) **L50:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10, неплохое значение по сравнению с другими показывает pacbio20 <br>
# 9) **LG50:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10, неплохое значение по сравнению с другими показывает pacbio20 <br>
# 10) **L75:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10, неплохое значение по сравнению с другими показывает pacbio20 <br>
# 11) **LG75:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10, неплохое значение по сравнению с другими показывает pacbio20 <br>
# 12) **# misassemblies:** здесь лучшие значения показывают illumina, illumina+pacbio20, illumina+pacbio40, худшие - все pacbio <br>
# 13) **# misassembled contigs:** лучшее - pacbio40, pacbio80, illumina, illumina+pacbio20, illumina+pacbio40, остальные значения приемлемы <br>
# 14) **# local misassemblies:** лучшее - pacbio10, pacbio40, pacbio80, остальные значения приемлемы <br>
# 15) **# unaligned contigs & unaligned length:** лучшее - все pacbio, остальные значения также хорошие <br>
# 16) **Genome fraction:** лучшее - pacbio40, pacbio80, остальные значения, кроме pacbio10, также очень хорошие <br>
# 17) **Duplication ratio:** лучшие значения показали все, кроме pacbio20 и pacbio80 <br>
# 18) **# mismatches per 100 kbp:** лучшее - pacbio40, pacbio80, приемлемое значение показывает illumina, худшее значение - pacbio10 <br>
# 19) **# indels per 100 kbp:** лучшее - illumina и гибридные сборки, худшее значение - pacbio10 <br>
# 20) **Largest alignment:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10 <br>
# 21) **Total aligned length:** лучшее - pacbio40, pacbio80, но остальные значения, кроме pacbio10, также хорошие <br>
# 22) **NA50:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10 <br>
# 23) **NGA50:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10 <br>
# 24) **NA75:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10 <br>
# 25) **NGA75:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10 <br>
# 26) **LA50:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10 <br>
# 27) **LGA50:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10 <br>
# 28) **LA75:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10 <br>
# 29) **LGA75:** лучшее - pacbio40, pacbio80, худшее значение - pacbio10 <br>

# %% [markdown]
# Таким образом, лучшие сборки по метрикам - pacbio40, pacbio80, худшая - pacbio10 (видимо, из-за низкого покрытия).
